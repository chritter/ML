# %%
# The code was removed by DSX for sharing.
# Out:
# Writing myfile.py

# %%
# !pwd;ls
# Out:
# /gpfs/fs01/user/s021-08766e6db051ab-1741987fe625/notebook/work
# myfile.py

# %%
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
df_data_1['HOUSE'].hist()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Third-party software

# %%
# !pip list --isolated
# Out:
# alabaster (0.7.8)
# anaconda-client (1.4.0)
# anaconda-navigator (1.2.1)
# argcomplete (1.0.0)
# astropy (1.2.1)
# astunparse (1.5.0)
# Babel (2.5.0)
# backports.shutil-get-terminal-size (1.0.0)
# backports.weakref (1.0rc1)
# beautifulsoup4 (4.4.1)
# biopython (1.66)
# bitarray (0.8.1)
# bkcharts (0.2)
# blaze (0.10.1)
# bleach (2.0.0)
# bokeh (0.12.7)
# boto (2.40.0)
# boto3 (1.4.4)
# botocore (1.5.50)
# Bottleneck (1.1.0)
# brunel (2.3)
# cdsax-jupyter-extensions (0.1)
# certifi (2017.7.27.1)
# cffi (1.6.0)
# chest (0.2.3)
# click (6.6)
# cloudpickle (0.2.1)
# clyent (1.2.2)
# cognitive-assistant (1.0.52)
# colorama (0.3.7)
# conda (4.3.27)
# conda-build (1.21.3)
# configobj (5.0.6)
# configparser (3.5.0)
# contextlib2 (0.5.3)
# cryptography (1.4)
# cycler (0.10.0)
# Cython (0.24)
# cytoolz (0.8.0)
# dask (0.10.0)
# datashape (0.5.2)
# debtcollector (1.17.0)
# decorator (4.0.10)
# dill (0.2.5)
# docutils (0.12)
# dynd (0.7.3.dev1)
# enum34 (1.1.5)
# et-xmlfile (1.0.1)
# ...

# %%
 # !pip install --user prettyplotlib
# Out:
# ...
#     100% |████████████████████████████████| 706kB 1.5MB/s eta 0:00:01    73% |███████████████████████▌        | 512kB 35.9MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for prettyplotlib ... done
#   Stored in directory: /gpfs/fs01/user/s021-08766e6db051ab-1741987fe625/.cache/pip/wheels/90/d9/9b/250de9b2ae1e874d5332e7f183c9e72e1ea172daea282d3eaa
# Successfully built prettyplotlib
# ...

# %%
# !ls ~/data/workdir

# %%
# %%writefile myfile.py
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.
